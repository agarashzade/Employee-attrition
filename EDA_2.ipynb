# %%
import os
os.chdir('C:/Users/AGarashzade/Documents/Personal/Employee-attrition')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('HR_Employee_Attrition.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.describe().transpose()
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
from matplotlib.pyplot import figure

figure(figsize=(20, 8), dpi=80)
#sns.barplot(x=df.corr().columns[15:-1], y=df.corr()['d_Attrition'].iloc[15:-1])
sns.barplot(x=df.corr().columns[:-15], y=df.corr()['d_Attrition'].iloc[:-15])

# %% [markdown]
# ### Cleaning the data and feature engineering

# %%
#To check the correlations, I add a dummy variable for Attrition
df['d_Attrition']=df['Attrition'].map({'Yes': 1, 'No': 0})

# %%
#The column is always 1 and does not serve for any purpose, we drop it
df=df.drop('EmployeeCount',axis=1)

# %%
df['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
#We reword the Business Travel column
df['BusinessTravel']=df['BusinessTravel'].map({'Travel_Rarely': 'Rare','Travel_Frequently': 'Frequent','Non-Travel':'Never'})
df=df.rename(columns={'BusinessTravel': 'TravelFrequency'})

# %%
df.head()
# Out:
#    Age Attrition TravelFrequency  DailyRate              Department  \
# 0   41       Yes            Rare       1102                   Sales
# 1   49        No        Frequent        279  Research & Development
# 2   37       Yes            Rare       1373  Research & Development
# 3   33        No        Frequent       1392  Research & Development
# 4   27        No            Rare        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  ... StandardHours  StockOptionLevel  \
# 0                        2  ...            80                 0
# ...

# %%
#Daily rate is likely to be very correlated with Hourly rate, Monthly rate and Monthly income

# %%
sns.color_palette('coolwarm')
sns.set()
sns.heatmap(df[['DailyRate','HourlyRate','MonthlyRate','MonthlyIncome','d_Attrition']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# It is not the case. Monthly income is the only one that seems to be correlated with attrition.

# %%
sns.countplot(x='Department',data=df)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
 df_for_plot_1=pd.crosstab(index=df['Department'],columns=df['Attrition'],normalize='index')

# %%
df_for_plot_1.plot(kind='bar',stacked='True')
plt.title('Around 20% attrition in Sales&HR, around 15% in R&D',fontsize=13,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Around 20% attrition in Sales&HR, around 15% in R&D')

# %%
sns.displot(data=df,x='Age',hue='Attrition')
plt.title('Higher attrition in low age groups',fontsize=15,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Higher attrition in low age groups')

# %%
#To demonstrate this better, I will create a column with age group: Below 30, 30 - 40, Above 40

df['Age_group']=np.where(df['Age']<=30,'1. Below 30',np.where(np.logical_and(df['Age']>30,df['Age']<=40),'2. 30 to 40','3. Above 40'))
df_for_plot_2=pd.crosstab(columns=df['Attrition'],index=df['Age_group'],normalize='index')
df_for_plot_2.plot(kind='bar',stacked=True)
plt.title('Almost 25% attrition for employees below 30',fontsize=15,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Almost 25% attrition for employees below 30')

# %%
sns.boxplot(x='Attrition',y='DistanceFromHome',data=df)
plt.title('Median distance from home is higher for employees who left',fontsize=15,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Median distance from home is higher for employees who left')

# %% [markdown]
# ### We join the dictionaries for some columns:
#
# **Education:**
# 1 'Below College' 2 'College' 3 'Bachelor' 4 'Master' 5 'Doctor'
#
# **EnvironmentSatisfaction:**
# 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
#
# **JobInvolvement:**
# 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
#
# **JobSatisfaction:**
# 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
#
# **PerformanceRating:**
# 1 'Low' 2 'Good' 3 'Excellent' 4 'Outstanding'
#
# **RelationshipSatisfaction:**
# 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
#
# **WorkLifeBalance:**
# 1 'Bad' 2 'Good' 3 'Better' 4 'Best'

# %%
dict_education=pd.DataFrame({'Education':[1,2,3,4,5],'Education_desc':['Below College','College','Bachelor','Master','Doctor']})
dict_env_sat=pd.DataFrame({'EnvironmentSatisfaction':[1,2,3,4],'Env_sat_desc':['Low','Medium','High','Very High']})
dict_job_involve=pd.DataFrame({'JobInvolvement':[1,2,3,4],'Job_involve_desc':['Low','Medium','High','Very High']})
dict_job_sat=pd.DataFrame({'JobSatisfaction':[1,2,3,4],'Job_sat_desc':['Low','Medium','High','Very High']})
dict_perf_rating=pd.DataFrame({'PerformanceRating':[1,2,3,4],'Perf_rating_desc':['Low','Good','Excellent','Outstanding']})
dict_relation_sat=pd.DataFrame({'RelationshipSatisfaction':[1,2,3,4],'Relation_sat_desc':['Low','Medium','High','Very High']})
dict_work_life=pd.DataFrame({'WorkLifeBalance':[1,2,3,4],'Work_life_desc':['Bad','Good','Better','Best']})

# %%
df=df.merge(dict_education,how='left',left_on='Education',right_on='Education')
df=df.merge(dict_env_sat,how='left',left_on='EnvironmentSatisfaction',right_on='EnvironmentSatisfaction')
df=df.merge(dict_job_involve,how='left',left_on='JobInvolvement',right_on='JobInvolvement')
df=df.merge(dict_job_sat,how='left',left_on='JobSatisfaction',right_on='JobSatisfaction')
df=df.merge(dict_perf_rating,how='left',left_on='PerformanceRating',right_on='PerformanceRating')
df=df.merge(dict_relation_sat,how='left',left_on='RelationshipSatisfaction',right_on='RelationshipSatisfaction')
df=df.merge(dict_work_life,how='left',left_on='WorkLifeBalance',right_on='WorkLifeBalance')

# %%
df.head()
# Out:
#    Age Attrition TravelFrequency  DailyRate              Department  \
# 0   41       Yes            Rare       1102                   Sales
# 1   49        No        Frequent        279  Research & Development
# 2   37       Yes            Rare       1373  Research & Development
# 3   33        No        Frequent       1392  Research & Development
# 4   27        No            Rare        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  ... YearsWithCurrManager  d_Attrition  \
# 0                        2  ...                    5            1
# ...

# %%
df.iloc[:,9:].head()
# Out:
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single           5993
# 1     Research Scientist                2       Married           5130
# 2  Laboratory Technician                3        Single           2090
# 3     Research Scientist                3       Married           2909
# 4  Laboratory Technician                2       Married           3468
#
#    MonthlyRate  ...  YearsWithCurrManager d_Attrition    Age_group  \
# ...

# %%
np.average(df[df['d_Attrition']==0]['Age'])
# Out:
# 37.561232765612324
